# %%
import numpy as np
import sys,os
import pandas as pd

# %%
file = "./TESSpointings.csv"
df = pd.read_csv(file)

lt = len(df['Sector'])
df
# Out:
#     Sector              Dates  Spacecraft-RA  Spacecraft-Dec  Spacecraft-roll  \
# 0        1  07/25/18-08/22/18         352.68          -64.85           222.15
# 1        2  08/22/18-09/20/18          16.56          -54.02           220.43
# 2        3  09/20/18-10/18/18          36.31          -44.26           213.04
# 3        4  10/18/18-11/15/18          55.01          -36.64           202.83
# 4        5  11/15/18-12/11/18          73.54          -31.93           191.05
# ..     ...                ...            ...             ...              ...
# 91      92  05/07/25-06/03/25         311.96          -17.14           285.42
# 92      93  06/03/25-06/29/25         260.52          -78.83           174.85
# 93      94  06/29/25-07/25/25         323.47          -74.90           215.85
# 94      95  07/25/25-08/20/25         355.70          -65.73           225.94
# 95      96  08/20/25-09/15/25          16.71          -55.94           223.76
#
# ...

# %%
for a in range(lt):
    
    print(f"Sector-{df['Sector'][a]}")
    
    print(f"""<h2>Spacecraft Pointing (deg)</h2>
    <div>
    <table class="table table-striped table-hover" style="max-width:40em;">
    <col style="width:20%">
    <col style="width:20%">
    <col style="width:20%">
    <col style="width:20%">
    
    <thead>
        <tr>
            <th style="vertical-align: right;"></th>
            <th style="vertical-align: middle;">RA</th>
            <th style="vertical-align: middle;">dec</th>
            <th style="vertical-align: middle;">roll</th>
        </tr>
    </thead>

    <tr>
      <td>Spacecraft</td>
      <td>{df['Spacecraft-RA'][a]}</td>
      <td>{df['Spacecraft-Dec'][a]}</td>
      <td>{df['Spacecraft-roll'][a]}</td>
    </tr>
    <tr>
      <td>Camera 1</td>
      <td>{df['Camera-1-RA'][a]}</td>
      <td>{df['Camera-1-Dec'][a]}</td>
      <td>{df['Camera-1-roll'][a]}</td>
    </tr>
    <tr>
      <td>Camera 2</td>
      <td>{df['Camera-2-RA'][a]}</td>
      <td>{df['Camera-2-Dec'][a]}</td>
      <td>{df['Camera-2-roll'][a]}</td>
    </tr>
    <tr>
      <td>Camera 3</td>
      <td>{df['Camera-3-RA'][a]}</td>
      <td>{df['Camera-3-Dec'][a]}</td>
      <td>{df['Camera-3-roll'][a]}</td>
    </tr>
    <tr>
      <td>Camera 4</td>
      <td>{df['Camera-4-RA'][a]}</td>
      <td>{df['Camera-4-Dec'][a]}</td>
      <td>{df['Camera-4-roll'][a]}</td>
    </tr>
    
  </table>
</div>

<br></br>""")
# Out:
# Sector-1
# <h2>Spacecraft Pointing (deg)</h2>
#     <div>
#     <table class="table table-striped table-hover" style="max-width:40em;">
#     <col style="width:20%">
#     <col style="width:20%">
#     <col style="width:20%">
#     <col style="width:20%">
#
#     <thead>
#         <tr>
#             <th style="vertical-align: right;"></th>
#             <th style="vertical-align: middle;">RA</th>
#             <th style="vertical-align: middle;">dec</th>
#             <th style="vertical-align: middle;">roll</th>
#         </tr>
#     </thead>
#
#     <tr>
#       <td>Spacecraft</td>
#       <td>352.68</td>
#       <td>-64.85</td>
#       <td>222.15</td>
#     </tr>
#     <tr>
#       <td>Camera 1</td>
#       <td>324.57</td>
#       <td>-33.17</td>
#       <td>289.92</td>
#     </tr>
#     <tr>
#       <td>Camera 2</td>
#       <td>338.58</td>
#       <td>-55.08</td>
#       <td>299.88</td>
#     </tr>
#     <tr>
#       <td>Camera 3</td>
#       <td>19.49</td>
# ...

# %%
<li><b>Pointing: </b>Southern hemisphere</li>
